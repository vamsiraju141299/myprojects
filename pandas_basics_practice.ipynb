# %% [markdown]
# PANDAS_BASICS_PRACTICE

# %% [markdown]
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'], 'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2], 'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# 1. Create a DataFrame birds from this dictionary data which has the index labels.

# %%
import pandas as pd
import numpy as np
birds_names=pd.DataFrame({
    'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
    'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
    'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
    'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']},
    index=['a','b','c','d','e','f','g','h','i','j']

     )
birds_names
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# 2. Display a summary of the basic information about birds DataFrame and its data.

# %%
birds_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
#   3. Print the first 2 rows of the birds dataframe

# %%
birds_names[:2]
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# b  Cranes  4.0       4      yes

# %% [markdown]
# 4. Print all the rows with only 'birds' and 'age' columns from the dataframe

# %%
birds_names[['birds','age']]
# Out:
#         birds  age
# a      Cranes  3.5
# b      Cranes  4.0
# c     plovers  1.5
# d  spoonbills  NaN
# e  spoonbills  6.0
# f      Cranes  3.0
# g     plovers  5.5
# h      Cranes  NaN
# i  spoonbills  8.0
# j  spoonbills  4.0

# %% [markdown]
# 5. select [2, 3, 7] rows and in columns ['birds', 'age', 'visits']

# %%
birds_names.iloc[[1,2,6],::-1]
# Out:
#   priority  visits  age    birds
# b      yes       4  4.0   Cranes
# c       no       3  1.5  plovers
# g       no       2  5.5  plovers

# %% [markdown]
# 6. select the rows where the number of visits is less than 4

# %%
print(birds_names[(birds_names['visits']<4)])
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# 7. select the rows with columns ['birds', 'visits'] where the age is missing i.e NaN

# %%
missing=birds_names[birds_names['age'].isnull()]
missing[['birds','visits']]
# Out:
#         birds  visits
# d  spoonbills       4
# h      Cranes       2

# %% [markdown]
# 8. Select the rows where the birds is a Cranes and the age is less than 4

# %%
birds_names[(birds_names['birds']=='Cranes') & (birds_names['visits']<4)]
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# h  Cranes  NaN       2      yes

# %% [markdown]
# 9. Select the rows the age is between 2 and 4(inclusive)

# %%
print(birds_names[(birds_names['age'].between(2, 4))])
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# f      Cranes  3.0       4       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# 10. Find the total number of visits of the bird Cranes

# %%
missing=birds_names.groupby('birds')
number_of_cranes=missing.get_group('Cranes')
number_of_cranes['visits'].sum()
# Out:
# 12

# %% [markdown]
# 11. Calculate the mean age for each different birds in dataframe.

# %%
missing=birds.groupby('birds')
missing['age'].mean()
# Out:
# birds
# plovers       3.5
# spoonbills    6.0
# trumpeters    3.5
# Name: age, dtype: float64

# %% [markdown]
# 12. Append a new row 'k' to dataframe with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
print("Orginal rows")
print(birds_names)
print()
print("Append a new row:\n")
birds_names.loc['k'] = ['Vamsi',20.0,5,'no']
print("Print all records after insert a new record:\n")
print(birds_names)
print()
print("Delete the new row and display the original  rows:\n")
birds_names = birds_names.drop('k')
print(birds_names)
# Out:
# Orginal rows
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
#
# Append a new row:
#
# Print all records after insert a new record:
#
#         birds   age  visits priority
# a      Cranes   3.5       2      yes
# b      Cranes   4.0       4      yes
# c     plovers   1.5       3       no
# d  spoonbills   NaN       4      yes
# e  spoonbills   6.0       3       no
# f      Cranes   3.0       4       no
# g     plovers   5.5       2       no
# h      Cranes   NaN       2      yes
# i  spoonbills   8.0       3       no
# j  spoonbills   4.0       2       no
# k       Vamsi  20.0       5       no
#
# ...

# %% [markdown]
# 13. Find the number of each type of birds in dataframe (Counts)

# %%
birds_names['birds'].nunique()
# Out:
# 3

# %% [markdown]
# 14. Sort dataframe (birds) first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order.

# %%
missing=birds_names.sort_values(by=['age', 'visits'], ascending=[False, True])
missing
# Out:
#         birds  age  visits priority
# i  spoonbills  8.0       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# j  spoonbills  4.0       2       no
# b      Cranes  4.0       4      yes
# a      Cranes  3.5       2      yes
# f      Cranes  3.0       4       no
# c     plovers  1.5       3       no
# h      Cranes  NaN       2      yes
# d  spoonbills  NaN       4      yes

# %% [markdown]
# 15. Replace the priority column values with'yes' should be 1 and 'no' should be 0

# %%
birds_names['priority'].replace(['yes', 'no'], [1, 0], inplace=True)
birds_names
# Out:
#         birds  age  visits  priority
# a      Cranes  3.5       2         1
# b      Cranes  4.0       4         1
# c     plovers  1.5       3         0
# d  spoonbills  NaN       4         1
# e  spoonbills  6.0       3         0
# f      Cranes  3.0       4         0
# g     plovers  5.5       2         0
# h      Cranes  NaN       2         1
# i  spoonbills  8.0       3         0
# j  spoonbills  4.0       2         0

# %% [markdown]
# 16. In the 'birds' column, change the 'Cranes' entries to 'trumpeters'.

# %%
birds_names['birds'].replace(['Cranes'], ['trumpeters'], inplace=True)
birds_names
# Out:
#         birds  age  visits  priority
# a  trumpeters  3.5       2         1
# b  trumpeters  4.0       4         1
# c     plovers  1.5       3         0
# d  spoonbills  NaN       4         1
# e  spoonbills  6.0       3         0
# f  trumpeters  3.0       4         0
# g     plovers  5.5       2         0
# h  trumpeters  NaN       2         1
# i  spoonbills  8.0       3         0
# j  spoonbills  4.0       2         0
